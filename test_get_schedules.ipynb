# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
import get_schedules

# %%
import importlib
importlib.reload(get_schedules)
# Out:
# <module 'get_schedules' from 'c:\\Users\\User\\Downloads\\courses\\get_schedules.py'>

# %%
cis = get_schedules.CourseInfoScraper('classes.xlsx', 'schedules.xlsx')

# %%
cis.scrape_course_info()
# Out:
# Numerical Analysis and Scientific Computing
# c:\Users\User\Downloads\courses\get_schedules.py:130: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if (course[-3:] in self.schedules_df['Course'].values and course[:3] in self.schedules_df['Department'].values) or course in self.schedules_df['Name'].values:

# %%
cis.schedules_df
# Out:
#    Department  Course                                               Name  \
# 0         AMS     317      Sondheim's Musicals and the Making of America
# 1         ANT     437  Gaming Blackness: The Anthropology of Video Ga...
# 2         ATL     498          Princeton Atelier: How to Write a Musical
# 3         DAN     215              Introduction to Dance Across Cultures
# 4         ECE     435           Machine Learning and Pattern Recognition
# 5         ECO     310      Microeconomic Theory: A Mathematical Approach
# 6         ECO     310      Microeconomic Theory: A Mathematical Approach
# 7         ECO     310      Microeconomic Theory: A Mathematical Approach
# 8         ECO     310      Microeconomic Theory: A Mathematical Approach
# 9         ECO     310      Microeconomic Theory: A Mathematical Approach
# 10        ECO     310      Microeconomic Theory: A Mathematical Approach
# 11        ECO     310      Microeconomic Theory: A Mathematical Approach
# 12        ENG     218                                        Nice People
# 13        ENG     291                                      Asian Mothers
# 14        ENG     401        Forms of Literature: American Short Stories
# 15        HUM     417        Historical Structures: Ancient Architecture
# 16        MUS     105   Music Theory through Performance and Composition
# 17        MUS     105   Music Theory through Performance and Composition
# 18        MUS     105   Music Theory through Performance and Composition
# 19        MUS     105   Music Theory through Performance and Composition
# 20        MUS     105   Music Theory through Performance and Composition
# 21        MUS     105   Music Theory through Performance and Composition
# 22        MUS     105   Music Theory through Performance and Composition
# 23        MUS     105   Music Theory through Performance and Composition
# 24        MUS     105   Music Theory through Performance and Composition
# 25        MUS     105   Music Theory through Performance and Composition
# 26        MUS     105   Music Theory through Performance and Composition
# 27        MUS     105   Music Theory through Performance and Composition
# 28        MUS     105   Music Theory through Performance and Composition
# 29        MUS     105   Music Theory through Performance and Composition
# 30        MUS     105   Music Theory through Performance and Composition
# 31        ORF     405                 Regression and Applied Time Series
# 32        ORF     405                 Regression and Applied Time Series
# 33        ORF     405                 Regression and Applied Time Series
# 34        ORF     405                 Regression and Applied Time Series
# 35        ORF     405                 Regression and Applied Time Series
# 36        PSY     341                        The Psychology of Adversity
# 37        REL     100               Religion and the Public Conversation
# 38        SPA     107                      Intermediate/Advanced Spanish
# 39        SPA     107                      Intermediate/Advanced Spanish
# 40        SPA     107                      Intermediate/Advanced Spanish
# 41        SPA     107                      Intermediate/Advanced Spanish
# 42        SPA     107                      Intermediate/Advanced Spanish
# 43        SPA     107                      Intermediate/Advanced Spanish
# 44        SPA     107                      Intermediate/Advanced Spanish
# 45        SPA     107                      Intermediate/Advanced Spanish
# 46        SPA     107                      Intermediate/Advanced Spanish
# 47        SPA     107                      Intermediate/Advanced Spanish
# 48        SPA     107                      Intermediate/Advanced Spanish
# 49        TRA     400                    Translation, Migration, Culture
# 50        MAT     345                                          Algebra I
# 51        LIN     360       Linguistic Universals and Language Diversity
# 52        LIN     250                           Language in Its Contexts
# 53        MPP     214  Projects in Vocal Performance: Singing America...
# 54        MAT     321        Numerical Analysis and Scientific Computing
# 55        MAT     321        Numerical Analysis and Scientific Computing
#
#    Section                                               Days     Start  \
# 0      S01                                        ['Tuesday']  13:30:00
# 1      S01                                      ['Wednesday']  13:30:00
# 2      C01                                      ['Wednesday']  13:30:00
# 3      S01                                      ['Wednesday']  13:30:00
# 4      L01                  ['Monday', 'Wednesday', 'Friday']  10:00:00
# 5      C01                                         ['Monday']  10:00:00
# 6      C02                                         ['Monday']  11:00:00
# 7      C03                                        ['Tuesday']  10:00:00
# 8      C04                                      ['Wednesday']  10:00:00
# 9      C05                                      ['Wednesday']  12:30:00
# 10     C06                                         ['Friday']  10:00:00
# 11     L01                            ['Tuesday', 'Thursday']  11:00:00
# 12     S01                            ['Monday', 'Wednesday']  13:30:00
# 13     S01                            ['Monday', 'Wednesday']  11:00:00
# 14     S01                            ['Monday', 'Wednesday']  13:30:00
# 15     S01                                         ['Monday']  13:30:00
# 16     E01                                         ['Friday']  09:00:00
# 17     E02                                         ['Friday']  10:00:00
# 18     E03                                         ['Friday']  11:00:00
# 19     E04                                         ['Friday']  12:30:00
# 20     E05                                         ['Friday']  13:30:00
# 21     E06                                         ['Friday']  14:30:00
# 22     E07                                         ['Friday']  15:30:00
# 23     E08                                         ['Friday']  10:00:00
# 24     L01                            ['Tuesday', 'Thursday']  12:30:00
# 25     P01                            ['Tuesday', 'Thursday']  13:30:00
# 26     P02                            ['Monday', 'Wednesday']  10:00:00
# 27     P03                            ['Tuesday', 'Thursday']  10:00:00
# 28     P04                            ['Tuesday', 'Thursday']  11:00:00
# 29     P05                            ['Monday', 'Wednesday']  11:00:00
# 30     P06                            ['Tuesday', 'Thursday']  09:00:00
# 31     B01                                      ['Wednesday']  20:30:00
# 32     B02                                      ['Wednesday']  20:30:00
# 33     L01                            ['Tuesday', 'Thursday']  15:00:00
# 34     P01                                      ['Wednesday']  19:30:00
# 35     P02                                      ['Wednesday']  19:30:00
# 36     S01                                       ['Thursday']  13:30:00
# 37     C01                            ['Tuesday', 'Thursday']  13:30:00
# 38     C01  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  09:00:00
# 39    C01A  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  09:00:00
# 40     C02  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  10:00:00
# 41    C02A  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  10:00:00
# 42    C02B  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  10:00:00
# 43    C02C  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  10:00:00
# 44     C03  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  11:00:00
# 45     C04  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  12:30:00
# 46    C04A  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  12:30:00
# 47    C04B  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  12:30:00
# 48    C04C  ['Monday', 'Tuesday', 'Wednesday', 'Thursday',...  12:30:00
# 49     S01                                      ['Wednesday']  13:30:00
# 50     C01                            ['Monday', 'Wednesday']  11:00:00
# 51     L01                            ['Monday', 'Wednesday']  15:00:00
# 52     L01                            ['Monday', 'Wednesday']  13:30:00
# 53     C01                            ['Tuesday', 'Thursday']  13:30:00
# 54     L01                            ['Tuesday', 'Thursday']  13:30:00
# 55     P01                                         ['Friday']  12:30:00
#
#          End
# 0   16:20:00
# 1   16:20:00
# 2   16:20:00
# 3   16:20:00
# 4   10:50:00
# 5   10:50:00
# 6   11:50:00
# 7   10:50:00
# 8   10:50:00
# 9   13:20:00
# 10  10:50:00
# 11  12:20:00
# 12  14:50:00
# 13  12:20:00
# 14  14:50:00
# 15  16:20:00
# 16  09:50:00
# 17  10:50:00
# 18  11:50:00
# 19  13:20:00
# 20  14:20:00
# 21  15:20:00
# 22  16:20:00
# 23  10:50:00
# 24  13:20:00
# 25  14:20:00
# 26  10:50:00
# 27  10:50:00
# 28  11:50:00
# 29  11:50:00
# 30  09:50:00
# 31  21:20:00
# 32  21:20:00
# 33  16:20:00
# 34  20:20:00
# 35  20:20:00
# 36  16:20:00
# 37  14:50:00
# 38  09:50:00
# 39  09:50:00
# 40  10:50:00
# 41  10:50:00
# 42  10:50:00
# 43  10:50:00
# 44  11:50:00
# 45  13:20:00
# 46  13:20:00
# 47  13:20:00
# 48  13:20:00
# 49  16:20:00
# 50  12:20:00
# 51  16:20:00
# 52  14:50:00
# 53  14:50:00
# 54  14:50:00
# 55  13:20:00

# %%
cis.save_schedules_df()
